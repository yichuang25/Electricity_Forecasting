# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Data/LD2011_2014.txt', sep=';',low_memory=False, decimal=',', parse_dates=True, index_col=0)
df
# Out:
#                        MT_001     MT_002    MT_003      MT_004     MT_005  \
# 2011-01-01 00:15:00  0.000000   0.000000  0.000000    0.000000   0.000000
# 2011-01-01 00:30:00  0.000000   0.000000  0.000000    0.000000   0.000000
# 2011-01-01 00:45:00  0.000000   0.000000  0.000000    0.000000   0.000000
# 2011-01-01 01:00:00  0.000000   0.000000  0.000000    0.000000   0.000000
# 2011-01-01 01:15:00  0.000000   0.000000  0.000000    0.000000   0.000000
# ...                       ...        ...       ...         ...        ...
# 2014-12-31 23:00:00  2.538071  22.048364  1.737619  150.406504  85.365854
# 2014-12-31 23:15:00  2.538071  21.337127  1.737619  166.666667  81.707317
# 2014-12-31 23:30:00  2.538071  20.625889  1.737619  162.601626  82.926829
# 2014-12-31 23:45:00  1.269036  21.337127  1.737619  166.666667  85.365854
# 2015-01-01 00:00:00  2.538071  19.914651  1.737619  178.861789  84.146341
#
#                          MT_006     MT_007      MT_008     MT_009     MT_010  \
# 2011-01-01 00:15:00    0.000000   0.000000    0.000000   0.000000   0.000000
# 2011-01-01 00:30:00    0.000000   0.000000    0.000000   0.000000   0.000000
# 2011-01-01 00:45:00    0.000000   0.000000    0.000000   0.000000   0.000000
# 2011-01-01 01:00:00    0.000000   0.000000    0.000000   0.000000   0.000000
# 2011-01-01 01:15:00    0.000000   0.000000    0.000000   0.000000   0.000000
# ...                         ...        ...         ...        ...        ...
# 2014-12-31 23:00:00  303.571429  11.305822  282.828283  68.181818  72.043011
# 2014-12-31 23:15:00  324.404762  11.305822  252.525253  64.685315  72.043011
# 2014-12-31 23:30:00  318.452381  10.175240  242.424242  61.188811  74.193548
# 2014-12-31 23:45:00  285.714286  10.175240  225.589226  64.685315  72.043011
# 2015-01-01 00:00:00  279.761905  10.175240  249.158249  62.937063  69.892473
#
#                      ...      MT_361   MT_362       MT_363       MT_364  \
# 2011-01-01 00:15:00  ...    0.000000      0.0     0.000000     0.000000
# 2011-01-01 00:30:00  ...    0.000000      0.0     0.000000     0.000000
# 2011-01-01 00:45:00  ...    0.000000      0.0     0.000000     0.000000
# 2011-01-01 01:00:00  ...    0.000000      0.0     0.000000     0.000000
# 2011-01-01 01:15:00  ...    0.000000      0.0     0.000000     0.000000
# ...                  ...         ...      ...          ...          ...
# 2014-12-31 23:00:00  ...  276.945039  28200.0  1616.033755  1363.636364
# 2014-12-31 23:15:00  ...  279.800143  28300.0  1569.620253  1340.909091
# 2014-12-31 23:30:00  ...  284.796574  27800.0  1556.962025  1318.181818
# 2014-12-31 23:45:00  ...  246.252677  28000.0  1443.037975   909.090909
# 2015-01-01 00:00:00  ...  188.436831  27800.0  1409.282700   954.545455
#
#                         MT_365    MT_366      MT_367      MT_368      MT_369  \
# 2011-01-01 00:15:00   0.000000  0.000000    0.000000    0.000000    0.000000
# 2011-01-01 00:30:00   0.000000  0.000000    0.000000    0.000000    0.000000
# 2011-01-01 00:45:00   0.000000  0.000000    0.000000    0.000000    0.000000
# 2011-01-01 01:00:00   0.000000  0.000000    0.000000    0.000000    0.000000
# 2012-01-01 01:15:00  15.645372   9.947338  556.628622   68.447412  723.607038
# ...                        ...        ...         ...         ...         ...
# 2014-12-31 23:00:00  29.986962   5.851375  697.102722  176.961603  651.026393
# 2014-12-31 23:15:00  29.986962   9.947338  671.641791  168.614357  669.354839
# 2014-12-31 23:30:00  27.379400   9.362200  670.763828  153.589316  670.087977
# 2014-12-31 23:45:00  26.075619   4.095963  664.618086  146.911519  646.627566
# 2015-01-01 00:00:00  27.379400   4.095963  628.621598  131.886477  673.020528
#
#                           MT_370
# 2012-01-01 00:15:00     0.000000
# 2012-01-01 00:30:00     0.000000
# 2012-01-01 00:45:00     0.000000
# 2012-01-01 01:00:00     0.000000
# 2012-01-01 01:15:00     0.000000
# ...                          ...
# 2014-12-31 23:00:00  7621.621622
# 2014-12-31 23:15:00  6702.702703
# 2014-12-31 23:30:00  6864.864865
# 2014-12-31 23:45:00  6540.540541
# 2015-01-01 00:00:00  7135.135135
#
# [105216 rows x 370 columns]

# %%
# drop row with all 0
df_filtered_15min.sum(axis=1)
# Out:
# 2012-01-01 00:15:00    120371.432507
# 2012-01-01 00:30:00    118439.493091
# 2012-01-01 00:45:00    117438.815666
# 2012-01-01 01:00:00    114412.922578
# 2012-01-01 01:15:00    112524.986162
#                            ...
# 2014-12-31 23:00:00    132288.754939
# 2014-12-31 23:15:00    128543.516567
# 2014-12-31 23:30:00    127478.208411
# 2014-12-31 23:45:00    125641.710272
# 2015-01-01 00:00:00    124214.199215
# Length: 105216, dtype: float64

# %%
# check yerly sum
df_filted_1y = df_filtered_15min.resample('Y').sum()
df_filted_1y
# Out:
#                    MT_001        MT_002         MT_003        MT_004  \
# 2012-12-31  193131.979695  9.431501e+05  272315.377932  3.501967e+06
# 2013-12-31  221593.908629  1.034917e+06   77092.962641  3.784563e+06
# 2014-12-31  142197.969543  9.348165e+05   59900.086881  4.240159e+06
# 2015-12-31       2.538071  1.991465e+01       1.737619  1.788618e+02
#
#                   MT_005        MT_006         MT_007        MT_008  \
# 2012-12-31  1.657138e+06  6.531205e+06  168867.721877  8.926296e+06
# 2013-12-31  1.743793e+06  6.745393e+06  259806.105144  9.118872e+06
# 2014-12-31  1.822162e+06  6.531110e+06  205460.712267  8.799788e+06
# 2015-12-31  8.414634e+01  2.797619e+02      10.175240  2.491582e+02
#
#                   MT_009        MT_010  ...        MT_361        MT_362  \
# 2012-12-31  1.932516e+06  1.869365e+06  ...  1.038898e+07  1.875699e+09
# 2013-12-31  1.893399e+06  2.130876e+06  ...  1.021319e+07  1.706354e+09
# 2014-12-31  1.780806e+06  1.919215e+06  ...  1.000342e+07  1.692666e+09
# 2015-12-31  6.293706e+01  6.989247e+01  ...  1.884368e+02  2.780000e+04
#
#                   MT_363        MT_364        MT_365         MT_366  \
# 2012-12-31  9.832168e+07  1.430611e+08  3.552548e+06  449068.461088
# 2013-12-31  8.623444e+07  1.411690e+08  2.708171e+06  459253.364541
# 2014-12-31  8.016549e+07  1.281261e+08  2.913841e+06  391806.319485
# 2015-12-31  1.409283e+03  9.545455e+02  2.737940e+01       4.095963
#
#                   MT_367        MT_368        MT_369        MT_370
# 2015-01-01 00:00:00  ...  175.438596  188.436831  27800.0  1409.282700
#
#                           MT_364     MT_365     MT_366      MT_367  \
# 2012-01-01 00:15:00  1704.545455  15.645372  12.873025  504.828797
# 2012-01-01 00:30:00  1659.090909  15.645372  13.458163  525.021949
# 2012-01-01 00:45:00  1636.363636  15.645372  10.532475  526.777875
# 2012-01-01 01:00:00  1636.363636  15.645372  14.628438  539.947322
# 2012-01-01 01:15:00  1659.090909  15.645372   9.947338  556.628622
# ...                          ...        ...        ...         ...
# 2014-12-31 23:00:00  1363.636364  29.986962   5.851375  697.102722
# 2014-12-31 23:15:00  1340.909091  29.986962   9.947338  671.641791
# 2014-12-31 23:30:00  1318.181818  27.379400   9.362200  670.763828
# 2014-12-31 23:45:00   909.090909  26.075619   4.095963  664.618086
# 2015-01-01 00:00:00   954.545455  27.379400   4.095963  628.621598
#
#                          MT_368      MT_369
# 2012-01-01 00:15:00   63.439065  761.730205
# 2012-01-01 00:30:00   60.100167  702.346041
# 2012-01-01 00:45:00   56.761269  696.480938
# 2012-01-01 01:00:00   63.439065  693.548387
# 2012-01-01 01:15:00   68.447412  723.607038
# ...                         ...         ...
# 2014-12-31 23:00:00  176.961603  651.026393
# 2014-12-31 23:15:00  168.614357  669.354839
# 2014-12-31 23:30:00  153.589316  670.087977
# 2014-12-31 23:45:00  146.911519  646.627566
# 2015-01-01 00:00:00  131.886477  673.020528
#
# [105216 rows x 330 columns]

# %%
df_filtered_90d = df_filtered_15min.resample('90D').sum()
colmns = df_filtered_90d.columns[(df_filtered_90d == 0).any()]
print(len(colmns))
# Out:
# 10

# %%
# remove colums contain only zeros in 90 days
df_filtered_15min = df_filtered_15min.drop(colmns, axis=1)
df_filtered_15min
# Out:
#                        MT_001     MT_002     MT_003      MT_004     MT_005  \
# 2012-01-01 00:15:00  3.807107  22.759602  77.324066  136.178862  70.731707
# 2012-01-01 00:30:00  5.076142  22.759602  77.324066  136.178862  73.170732
# 2012-01-01 00:45:00  3.807107  22.759602  77.324066  140.243902  69.512195
# 2012-01-01 01:00:00  3.807107  22.759602  77.324066  140.243902  75.609756
# 2012-01-01 01:15:00  5.076142  22.048364  77.324066  146.341463  73.170732
# ...                       ...        ...        ...         ...        ...
# 2014-12-31 23:00:00  2.538071  22.048364   1.737619  150.406504  85.365854
# 2014-12-31 23:15:00  2.538071  21.337127   1.737619  166.666667  81.707317
# 2014-12-31 23:30:00  2.538071  20.625889   1.737619  162.601626  82.926829
# 2014-12-31 23:45:00  1.269036  21.337127   1.737619  166.666667  85.365854
# 2015-01-01 00:00:00  2.538071  19.914651   1.737619  178.861789  84.146341
#
#                          MT_006     MT_007      MT_008     MT_009     MT_010  \
# 2012-01-01 00:15:00  351.190476   9.609949  279.461279  75.174825  87.096774
# 2012-01-01 00:30:00  354.166667   9.044658  279.461279  73.426573  84.946237
# 2012-01-01 00:45:00  348.214286   8.479367  279.461279  75.174825  91.397849
# 2012-01-01 01:00:00  339.285714   7.348785  279.461279  68.181818  88.172043
# 2012-01-01 01:15:00  342.261905   6.783493  265.993266  69.930070  86.021505
# ...                         ...        ...         ...        ...        ...
# 2014-12-31 23:00:00  303.571429  11.305822  282.828283  68.181818  72.043011
# 2014-12-31 23:15:00  324.404762  11.305822  252.525253  64.685315  72.043011
# 2014-12-31 23:30:00  318.452381  10.175240  242.424242  61.188811  74.193548
# 2014-12-31 23:45:00  285.714286  10.175240  225.589226  64.685315  72.043011
# 2015-01-01 00:00:00  279.761905  10.175240  249.158249  62.937063  69.892473
#
#                      ...      MT_360      MT_361   MT_362       MT_363  \
# 2012-01-01 00:15:00  ...  223.684211  128.479657  28500.0  1729.957806
# 2012-01-01 00:30:00  ...  236.842105  127.765882  26400.0  1654.008439
# 2012-01-01 00:45:00  ...  214.912281  114.204140  25200.0  1333.333333
# 2012-01-01 01:00:00  ...  200.657895  112.062812  23800.0  1324.894515
# 2012-01-01 01:15:00  ...  199.561404  112.776588  23700.0  1118.143460
# ...                  ...         ...         ...      ...          ...
# 2014-12-31 23:00:00  ...  206.140351  276.945039  28200.0  1616.033755
# 2014-12-31 23:15:00  ...  192.982456  279.800143  28300.0  1569.620253
# 2014-12-31 23:30:00  ...  191.885965  284.796574  27800.0  1556.962025
# 2014-12-31 23:45:00  ...  190.789474  246.252677  28000.0  1443.037975
# 2015-01-01 00:00:00  ...  175.438596  188.436831  27800.0  1409.282700
#
#                           MT_364     MT_365     MT_366      MT_367  \
# 2012-01-01 00:15:00  1704.545455  15.645372  12.873025  504.828797
# 2012-01-01 00:30:00  1659.090909  15.645372  13.458163  525.021949
# 2012-01-01 00:45:00  1636.363636  15.645372  10.532475  526.777875
# 2012-01-01 01:00:00  1636.363636  15.645372  14.628438  539.947322
# 2012-01-01 01:15:00  1659.090909  15.645372   9.947338  556.628622
# ...                          ...        ...        ...         ...
# 2014-12-31 23:00:00  1363.636364  29.986962   5.851375  697.102722
# 2014-12-31 23:15:00  1340.909091  29.986962   9.947338  671.641791
# 2014-12-31 23:30:00  1318.181818  27.379400   9.362200  670.763828
# 2014-12-31 23:45:00   909.090909  26.075619   4.095963  664.618086
# 2015-01-01 00:00:00   954.545455  27.379400   4.095963  628.621598
#
#                          MT_368      MT_369
# 2012-01-01 00:15:00   63.439065  761.730205
# 2012-01-01 00:30:00   60.100167  702.346041
# 2012-01-01 00:45:00   56.761269  696.480938
# 2012-01-01 01:00:00   63.439065  693.548387
# 2012-01-01 01:15:00   68.447412  723.607038
# ...                         ...         ...
# 2014-12-31 23:00:00  176.961603  651.026393
# 2014-12-31 23:15:00  168.614357  669.354839
# 2014-12-31 23:30:00  153.589316  670.087977
# 2014-12-31 23:45:00  146.911519  646.627566
# 2015-01-01 00:00:00  131.886477  673.020528
#
# [105216 rows x 320 columns]

# %%
df_filtered_15min.replace(0, np.nan, inplace=True)
df_filtered_15min.isnull().sum()
# Out:
# MT_129    0
# MT_156    0
# MT_158    0
# MT_159    0
# MT_166    0
#          ..
# MT_324    0
# MT_326    0
# MT_327    0
# MT_329    0
# MT_330    0
# Length: 92, dtype: int64

# %%
# impute missing values
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn import linear_model


mice_imputer = IterativeImputer(missing_values=np.nan, random_state=42, initial_strategy='median',estimator=linear_model.BayesianRidge(),n_nearest_features=5)

df_filtered_15min = pd.DataFrame(mice_imputer.fit_transform(df_filtered_15min), columns=df_filtered_15min.columns, index=df_filtered_15min.index)
df_filtered_15min
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [42], line 9
#       4 from sklearn import linear_model
#       7 mice_imputer = IterativeImputer(missing_values=np.nan, random_state=42, initial_strategy='median',estimator=linear_model.BayesianRidge(),n_nearest_features=5)
# ----> 9 df_filtered_15min = pd.DataFrame(mice_imputer.fit_transform(df_filtered_15min), columns=df_filtered_15min.columns, index=df_filtered_15min.index)
#      10 df_filtered_15min
#
# File /opt/homebrew/lib/python3.9/site-packages/sklearn/impute/_iterative.py:678, in IterativeImputer.fit_transform(self, X, y)
#     674 for feat_idx in ordered_idx:
#     675     neighbor_feat_idx = self._get_neighbor_feat_idx(
#     676         n_features, feat_idx, abs_corr_mat
#     677     )
# --> 678     Xt, estimator = self._impute_one_feature(
#     679         Xt,
#     680         mask_missing_values,
#     681         feat_idx,
#     682         neighbor_feat_idx,
#     683         estimator=None,
#     684         fit_mode=True,
#     685     )
#     686     estimator_triplet = _ImputerTriplet(
#     687         feat_idx, neighbor_feat_idx, estimator
#     688     )
#     689     self.imputation_sequence_.append(estimator_triplet)
#
# File /opt/homebrew/lib/python3.9/site-packages/sklearn/impute/_iterative.py:331, in IterativeImputer._impute_one_feature(self, X_filled, mask_missing_values, feat_idx, neighbor_feat_idx, estimator, fit_mode)
#     329     X_train = _safe_indexing(X_filled[:, neighbor_feat_idx], ~missing_row_mask)
#     330     y_train = _safe_indexing(X_filled[:, feat_idx], ~missing_row_mask)
# --> 331     estimator.fit(X_train, y_train)
#     333 # if no missing values, don't predict
#     334 if np.sum(missing_row_mask) == 0:
#
# File /opt/homebrew/lib/python3.9/site-packages/sklearn/linear_model/_bayes.py:283, in BayesianRidge.fit(self, X, y, sample_weight)
#     280 coef_old_ = None
#     282 XT_y = np.dot(X.T, y)
# --> 283 U, S, Vh = linalg.svd(X, full_matrices=False)
#     284 eigen_vals_ = S**2
#     286 # Convergence loop of the bayesian ridge regression
#
# File /opt/homebrew/lib/python3.9/site-packages/scipy/linalg/_decomp_svd.py:127, in svd(a, full_matrices, compute_uv, overwrite_a, check_finite, lapack_driver)
#     123 lwork = _compute_lwork(gesXd_lwork, a1.shape[0], a1.shape[1],
#     124                        compute_uv=compute_uv, full_matrices=full_matrices)
#     126 # perform decomposition
# --> 127 u, s, v, info = gesXd(a1, compute_uv=compute_uv, lwork=lwork,
#     128                       full_matrices=full_matrices, overwrite_a=overwrite_a)
#     130 if info > 0:
#     131     raise LinAlgError("SVD did not converge")
#
# KeyboardInterrupt:

# %%
df_filtered_1h = df_filtered_15min.resample('H').sum()
df_filtered_1h.replace(0, np.nan, inplace=True)
df_filtered_1h.isnull().sum()
# Out:
# MT_001     38
# MT_002      1
# MT_003    149
# MT_004      3
# MT_005      3
#          ...
# MT_365      3
# MT_366     16
# MT_367     11
# MT_368      4
# MT_369      3
# Length: 320, dtype: int64

# %%
df_filtered_1d = df_filtered_15min.resample('D').sum()
df_filtered_1d.replace(0, np.nan, inplace=True)
df_filtered_1d.isnull().sum()
# Out:
# MT_001    0
# MT_002    0
# MT_003    0
# MT_004    0
# MT_005    0
#          ..
# MT_365    0
# MT_366    0
# MT_367    0
# MT_368    0
# MT_369    0
# Length: 320, dtype: int64

# %%
df_filtered_1d['MT_004'].plot()
# Out:
# <AxesSubplot: >
